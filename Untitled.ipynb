# %%
#Reading the csv file
import pandas as pd 
df_cpi = pd.read_csv('CPI2019.csv', skiprows=2)
df_cpi = df_cpi[df_cpi["Country"].isin(['Switzerland', 'Spain', 'United Kingdom', 'OECD - Total'])]
df_cpi.drop([col for col in df_cpi.columns if "Sources" in col], axis=1, inplace=True)
df_cpi.drop([col for col in df_cpi.columns if "Rank" in col], axis=1, inplace=True)
df_cpi.drop(['ISO3','Region'], axis=1, inplace=True)
df_cpi.replace(' ','')
#
df_cpi.index.name = 'Index'
df_cpi.set_index('Country', inplace=True)
#df_cpi.reset_index(drop=True, inplace=True)
df_cpi
# Out:
#                 CPI score 2019  Standard error 2019  CPI score 2018  \
# Country
# Switzerland                 85                 1.58              85
# United Kingdom              77                 3.34              80
# Spain                       62                 3.17              58
#
#                 Standard error 2018  CPI score 2017  Standard error 2017  \
# Country
# Switzerland                    1.57              85                 1.71
# United Kingdom                 2.03              82                 1.70
# Spain                          4.33              57                 3.78
#
#                 CPI score 2016  Standard error 2016  CPI score 2015  \
# Country
# Switzerland               86.0                 1.57            86.0
# United Kingdom            81.0                 2.12            81.0
# Spain                     58.0                 4.09            58.0
#
#                 Standard error 2015  CPI score 2014  Standard error 2014  \
# Country
# ...

# %%
cpi_tr = df_cpi.T #.astype(float)
cpi_tr.rename(columns = cpi_tr.iloc[0]).drop(cpi_tr.index[0])
#cpi_tr.rename(columns = {'': 'Category'}, inplace=True)
cpi_tr
# Out:
# Country              Switzerland  United Kingdom  Spain
# CPI score 2019             85.00           77.00  62.00
# Standard error 2019         1.58            3.34   3.17
# CPI score 2018             85.00           80.00  58.00
# Standard error 2018         1.57            2.03   4.33
# CPI score 2017             85.00           82.00  57.00
# Standard error 2017         1.71            1.70   3.78
# CPI score 2016             86.00           81.00  58.00
# Standard error 2016         1.57            2.12   4.09
# CPI score 2015             86.00           81.00  58.00
# Standard error 2015         2.55            2.40   4.07
# CPI score 2014             86.00           78.00  60.00
# Standard error 2014         2.61            2.09   3.75
# CPI Score 2013             85.00           76.00  59.00
# Standard error 2013         2.50            1.30   4.90
# CPI Score 2012             86.00           74.00  65.00
# Standard error 2012         2.60            1.30   2.90

# %%
cpi_score = df[df['Country'].str.contains('score')]
#df=cpi_tr.reset_index()
cpi_score
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-158-ec1802d2bbf8> in <module>
# ...

# %%
cpi_score = df[df['index'].str.contains('score')]


#cpi_score.rename(columns={'Switzerland': 'CHE_CPI', 'United Kingdom': 'GBR_CPI', 'Spain':'SPA_CPI'}, inplace=True)

cpi_score
# Out:
# Country           index  Switzerland  United Kingdom  Spain
# 0        CPI score 2019         85.0            77.0   62.0
# 2        CPI score 2018         85.0            80.0   58.0
# 4        CPI score 2017         85.0            82.0   57.0
# 6        CPI score 2016         86.0            81.0   58.0
# 8        CPI score 2015         86.0            81.0   58.0
# 10       CPI score 2014         86.0            78.0   60.0

# %%
cpi_serr = df[df['index'].str.contains('error')]
cpi_serr['Year']=['2019','2018','2017','2016','2015','2014','2013','2012']
cpi_serr.set_index('Year', inplace=True)
cpi_serr.head()
# Out:
# /Users/rogermoll/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Country                index  Switzerland  United Kingdom  Spain
# Year
# 2019     Standard error 2019         1.58            3.34   3.17
# 2018     Standard error 2018         1.57            2.03   4.33
# 2017     Standard error 2017         1.71            1.70   3.78
# 2016     Standard error 2016         1.57            2.12   4.09
# 2015     Standard error 2015         2.55            2.40   4.07

# %%
#years =
#cpi_score.index.names['Year']
#cpi_score.set_index('Country', inplace=True)
#cpi_score['Year'] = years
#cpi_score.set_index('Year', inplace=True)

#cpi_score.drop('index', axis=1, inplace=True)
#cpi_score.loc['Year'] = ['2019','2018','2017','2016','2015','2014','2013','2012']
